# %% [markdown]
# <a href="https://colab.research.google.com/github/mejihero/demo-image-classification-fastai/blob/master/Copy_of_image_classification_with_fastai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/wshuyi/demo-image-classification-fastai.git
# Out:
# Cloning into 'demo-image-classification-fastai'...
# remote: Enumerating objects: 382, done.
# remote: Total 382 (delta 0), reused 0 (delta 0), pack-reused 382
# Receiving objects: 100% (382/382), 52.42 MiB | 9.31 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
from fastai.vision import *

# %%
path = Path("demo-image-classification-fastai/imgs")

# %%
print(path)
# Out:
# demo-image-classification-fastai/imgs

# %%
# data = ImageDataBunch.from_folder(path, test='test', ds_tfms=get_transforms(), size=224)
data = ImageDataBunch.from_folder(path, test='test', size=224)

# %%
data.show_batch(rows=3, figsize=(10,10))

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
# 100%|██████████| 44.7M/44.7M [00:01<00:00, 46.0MB/s]

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.724688</td>
#       <td>0.103811</td>
#       <td>0.969697</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(10,10))

# %%
interp.plot_confusion_matrix()

# %%
img = learn.data.test_ds[0][0]

# %%
img
# Out:
# Image (3, 224, 224)

# %%
learn.predict(img)
# Out:
# (Category walle, tensor(1), tensor([0.0010, 0.9990]))
